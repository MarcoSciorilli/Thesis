# %%
import uproot
# %matplotlib inline
import matplotlib.pyplot as plt
import math
#import ROOT
import numpy as np
import pandas as pd

# %%
plt.rcParams.update({
          'font.size': 20,
          'figure.figsize': (11, 10),
          'axes.grid': True,
          'grid.linestyle': '-',
          'grid.alpha': 0.2,
          'lines.markersize': 5.0,
          'xtick.minor.visible': True,
          'xtick.direction': 'in',
          'xtick.major.size': 10.0,
          'xtick.minor.size': 5.0,
          'xtick.top': True,
          'ytick.minor.visible': True,
          'ytick.direction': 'in',
          'ytick.major.size': 10.0,
          'ytick.minor.size': 5.0,
          'ytick.right': True,
          'errorbar.capsize': 0.0,
})

# %%
dfbk = uproot.open('~/Desktop/Tesi/Ntuples/B0DpiMC.root')['B0Dpi']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-50120ec41862> in <module>
# ----> 1 dfbk = uproot.open('~/Desktop/Tesi/Ntuples/B0DpiMC.root')['B0Dpi']
#
# ~/.local/lib/python3.8/site-packages/uproot/rootio.py in open(path, localsource, xrootdsource, httpsource, **options)
#      52         else:
#      53             openfcn = localsource
# ---> 54         return ROOTDirectory.read(openfcn(path), **options)
#      55
#      56     elif _bytesid(parsed.scheme) == b"root":
#
# ~/.local/lib/python3.8/site-packages/uproot/rootio.py in <lambda>(path)
#      49                 if n in options:
#      50                     kwargs[n] = options.pop(n)
# ---> 51             openfcn = lambda path: MemmapSource(path, **kwargs)
#      52         else:
#      53             openfcn = localsource
#
# ...

# %%
dfbk1=dfbk.pandas.df(['pi_PIDpair_expert_pion','deltae','mbc','CSMVA','isSignal','isContinuumEvent','K_PIDpair_expert_kaon','R2','thrustBm','thrustOm','cosTBTO','cosTBz','KSFWVariables__boet__bc','KSFWVariables__bomm2__bc','KSFWVariables__bohso00__bc','KSFWVariables__bohso02__bc','KSFWVariables__bohso04__bc','KSFWVariables__bohso10__bc','KSFWVariables__bohso12__bc','KSFWVariables__bohso14__bc','KSFWVariables__bohso20__bc','KSFWVariables__bohso22__bc','KSFWVariables__bohso24__bc','KSFWVariables__bohoo0__bc','KSFWVariables__bohoo1__bc','KSFWVariables__bohoo2__bc','KSFWVariables__bohoo3__bc','KSFWVariables__bohoo4__bc','CleoConeCS__bo1__bc','CleoConeCS__bo2__bc','CleoConeCS__bo3__bc','CleoConeCS__bo4__bc','CleoConeCS__bo5__bc','CleoConeCS__bo6__bc','CleoConeCS__bo7__bc','CleoConeCS__bo8__bc'])

# %%
dfbk1.describe()
# Out:
#        pi_PIDpair_expert_pion         deltae            mbc          CSMVA  \
# count            1.986130e+05  198613.000000  198613.000000  198613.000000
# mean             7.254570e-01      -0.450973       5.243029       0.201753
# std              3.897268e-01       0.468715       0.024567       0.283124
# min              4.747055e-55      -0.999998       5.200000       0.000024
# 25%              4.561235e-01      -0.825678       5.222020       0.012466
# 50%              9.995789e-01      -0.585291       5.243023       0.057418
# 75%              1.000000e+00      -0.190356       5.263698       0.272949
# max              1.000000e+00       0.999955       5.289771       0.999403
#
#             isSignal  isContinuumEvent  K_PIDpair_expert_kaon             R2  \
# count  198613.000000     198613.000000          198613.000000  198613.000000
# mean        0.007316          0.770967               0.966701       0.332586
# ...

# %%
label1='Signal'
label2='Background'

# %%
nbins = 40
myrange = (-0.05,1)
plt.hist(dfbkp.R2[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.R2[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (0.77,1.01)
plt.hist(dfbkp.thrustBm[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.thrustBm[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (0.5,1)
plt.hist(dfbkp.thrustOm[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.thrustOm[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-0.05,1.1)
plt.hist(dfbkp.cosTBTO[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.cosTBTO[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-0.1,1.01)
plt.hist(dfbkp.cosTBz[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.cosTBz[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (2,14)
plt.hist(dfbkp.KSFWVariables__boet__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__boet__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-35,25)
plt.hist(dfbkp.KSFWVariables__bomm2__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bomm2__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label=label2, density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-0.15,1.7)
plt.hist(dfbkp.KSFWVariables__bohso00__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso00__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-0.6,1.)
plt.hist(dfbkp.KSFWVariables__bohso02__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso02__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
myrange = (-0.5,0.8)
plt.hist(dfbkp.KSFWVariables__bohso04__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso04__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['cosTBTO'].max()
min1=dfbk1['cosTBTO'].min()
myrange = (min1-0.1,max1+0.1)
plt.hist(dfbkp.cosTBTO[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.cosTBTO[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso10__bc'].max()
min1=dfbk1['KSFWVariables__bohso10__bc'].min()
myrange = (min1-0.1,max1+0.1)
plt.hist(dfbkp.KSFWVariables__bohso10__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso10__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso12__bc'].max()
min1=dfbk1['KSFWVariables__bohso12__bc'].min()
myrange = (min1-0.1,max1+0.1)
plt.hist(dfbkp.KSFWVariables__bohso12__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso12__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso14__bc'].max()
min1=dfbk1['KSFWVariables__bohso14__bc'].min()
print(-0.3,0.4)
myrange = (min1-0.1,max1+0.1)
plt.hist(dfbkp.KSFWVariables__bohso14__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso14__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# -0.3 0.4
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso20__bc'].max()
min1=dfbk1['KSFWVariables__bohso20__bc'].min()
myrange = (-0.01,0.7)
plt.hist(dfbkp.KSFWVariables__bohso20__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso20__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso22__bc'].max()
min1=dfbk1['KSFWVariables__bohso22__bc'].min()
myrange = (-0.3,+0.5)
plt.hist(dfbkp.KSFWVariables__bohso22__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso22__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohso24__bc'].max()
min1=dfbk1['KSFWVariables__bohso24__bc'].min()
myrange = (-0.3,0.4)
plt.hist(dfbkp.KSFWVariables__bohso24__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohso24__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo0__bc'].max()
min1=dfbk1['KSFWVariables__bohoo0__bc'].min()
myrange = (-0.025,0.4)
plt.hist(dfbkp.KSFWVariables__bohoo0__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo0__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo1__bc'].max()
min1=dfbk1['KSFWVariables__bohoo1__bc'].min()
myrange = (-0.03,0.03)
plt.hist(dfbkp.KSFWVariables__bohoo1__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo1__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo2__bc'].max()
min1=dfbk1['KSFWVariables__bohoo2__bc'].min()
myrange = (-0.05,0.15)
plt.hist(dfbkp.KSFWVariables__bohoo2__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo2__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo3__bc'].max()
min1=dfbk1['KSFWVariables__bohoo3__bc'].min()
myrange = (-0.03,0.03)
plt.hist(dfbkp.KSFWVariables__bohoo3__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo3__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo4__bc'].max()
min1=dfbk1['KSFWVariables__bohoo4__bc'].min()
myrange = (-0.05,0.07)
plt.hist(dfbkp.KSFWVariables__bohoo4__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo4__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['KSFWVariables__bohoo4__bc'].max()
min1=dfbk1['KSFWVariables__bohoo4__bc'].min()
myrange = (-0.03,0.075)
plt.hist(dfbkp.KSFWVariables__bohoo4__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.KSFWVariables__bohoo4__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo1__bc'].max()
min1=dfbk1['CleoConeCS__bo1__bc'].min()
myrange = (min1-0.1,8)
plt.hist(dfbkp.CleoConeCS__bo1__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo1__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo2__bc'].max()
min1=dfbk1['CleoConeCS__bo2__bc'].min()
myrange = (min1-0.1,7)
plt.hist(dfbkp.CleoConeCS__bo2__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo2__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo3__bc'].max()
min1=dfbk1['CleoConeCS__bo3__bc'].min()
myrange = (min1-0.1,5)
plt.hist(dfbkp.CleoConeCS__bo3__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo3__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo4__bc'].max()
min1=dfbk1['CleoConeCS__bo4__bc'].min()
myrange = (min1-0.1,5)
plt.hist(dfbkp.CleoConeCS__bo4__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo4__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo5__bc'].max()
min1=dfbk1['CleoConeCS__bo5__bc'].min()
myrange = (min1-0.1,5)
plt.hist(dfbkp.CleoConeCS__bo5__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo5__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo6__bc'].max()
min1=dfbk1['CleoConeCS__bo6__bc'].min()
myrange = (min1-0.1,4)
plt.hist(dfbkp.CleoConeCS__bo6__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo6__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo7__bc'].max()
min1=dfbk1['CleoConeCS__bo7__bc'].min()
myrange = (min1-0.1,4)
plt.hist(dfbkp.CleoConeCS__bo7__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo7__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')

# %%
nbins = 40
max1=dfbk1['CleoConeCS__bo8__bc'].max()
min1=dfbk1['CleoConeCS__bo8__bc'].min()
myrange = (min1-0.1,4)
plt.hist(dfbkp.CleoConeCS__bo8__bc[(dfbk1.isSignal==1)],nbins,myrange,histtype='step',lw=2,label=label1,density=True)
plt.hist(dfbkp.CleoConeCS__bo8__bc[(dfbk1.isSignal<=0)],nbins,myrange,histtype='step',lw=2,label='BtoDkpi_Background', density=True)
plt.legend(loc=0)
b2.errorhist(dfoffresp.cosTBTO,bins=nbins,range=myrange,label='off-resonance data',normed = 1 ,color = 'black')
b2.hist(dfudscp.cosTBTO,bins=nbins,range=myrange,label='udsc MC',normed = 1)
plt.legend(loc=0)
plt.xlabel('cosTBTO',fontsize=30)
plt.xlabel('$\\Delta E$ (GeV)',fontsize=30)
# Out:
# Text(0.5, 0, '$\\Delta E$ (GeV)')
